# %%
# --- Bootstrap ---
# !git clone https://github.com/dfox0207/FIRE.git
# %cd FIRE
# !pip install -r requirements.txt
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content 
# !pwd
# !ls

# %%
rm -rf FIRE

# %%
# %cd /content/FIRE
# !git fetch origin
# !git checkout -b optimizer origin/optimizer
# !git pull origin optimizer
# !git log -1 --oneline
# !git branch

# %%
# %cd /content/FIRE
# !git fetch
# !git pull
# !git log -1 --oneline

# %%
# !python src/Balances_update.py

# %%
run src/run_projection.py /content/drive/MyDrive/Finances/FIRE/Classic.json
