# %%
# --- Bootstrap ---
# !git clone https://github.com/dfox0207/FIRE.git
# %cd FIRE
# !pip install -r requirements.txt
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content 
# !pwd
# !ls

# %%
rm -rf FIRE

# %%
# !python src/projections.py

# %%
run src/plot_nominal.py
